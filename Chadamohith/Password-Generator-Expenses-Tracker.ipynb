# %% [markdown]
# <a href="https://colab.research.google.com/github/Chadamohith/Password-Generator-Expenses-Tracker/blob/main/Chadamohith/Password-Generator-Expenses-Tracker.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# expense_tracker.py
expenses = []

while True:
    amt = input("Enter expense (or q to quit): ")
    if amt == "q":
        break
    expenses.append(float(amt))

print("Total Expense:", sum(expenses))
# Out:
# Enter expense (or q to quit): 2
# Enter expense (or q to quit): 5
# Enter expense (or q to quit): 6
# Enter expense (or q to quit): q
# Total Expense: 13.0

# %%
# password_generator.py
import random
import string

length = int(input("Length: "))
chars = string.ascii_letters + string.digits + "!@#$%"
password = "".join(random.choice(chars) for _ in range(length))
print("Password:", password)
# Out:
# Length: 5
# Password: o2!Bz
